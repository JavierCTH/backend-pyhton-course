# %%
import requests

print("Lista de Reproducción\n")

# Referencia: https://www.deezer.com/en/channels/explore

print("Ingresa la palabra que te gustaría\n")
print("Ejemplo: 'rock', y obtendrás un playlist de canciones o artistas que incluyan la palabra rock\n")

word_to_search = input()

url = "https://deezerdevs-deezer.p.rapidapi.com/search"
querystring = {"q":word_to_search}
headers = {
    "X-RapidAPI-Key": "3ed98f551fmshe4e6260228c4eadp13db17jsn8c893e1194da",
    "X-RapidAPI-Host": "deezerdevs-deezer.p.rapidapi.com"
}
response = requests.request("GET", url, headers=headers, params=querystring).json()

my_list = []

for element in response['data']:
    my_dict = {"Artist": element['artist']['name'],
              "Song": element['title']}
    my_list.append(my_dict)


# Convencional
for element in my_list:
    print("\n", element)

# Comprehension
elements = [element for element in my_list]
print("\n", elements)
# Out:
# Lista de Reproducción
#
# Ingresa la palabra que te gustaría
#
# Ejemplo: 'rock', y obtendrás un playlist de canciones o artistas que incluyan la palabra rock
#
# symphonic metal
#
#  {'Artist': 'Infinite Rock', 'Song': 'Symphonic Metal'}
#
#  {'Artist': 'The Tiberian Sons', 'Song': 'Mighty Wings (From "Top Gun") (Symphonic Metal Version)'}
#
#  {'Artist': 'Metal Militia', 'Song': 'Nothing Else Matters (Symphonic Version) (as made famous by Metallica)'}
#
#  {'Artist': 'Epic Symphonic Rock', 'Song': 'Metallica I (Live)'}
#
#  {'Artist': "Orion's Reign", 'Song': 'Santa Claus Is Coming to Town (Symphonic Heavy Metal Version)'}
#
#  {'Artist': 'NyxTheShield', 'Song': 'Black Apple (From "Underverse") (Symphonic Metal Version)'}
#
#  {'Artist': "Orion's Reign", 'Song': 'Thunderstruck (Symphonic Heavy Metal Version)'}
#
#  {'Artist': "Orion's Reign", 'Song': 'Joy to the World (Symphonic Heavy Metal Version)'}
#
#  {'Artist': 'BrunuhVille', 'Song': '[bonus] Lua Eterna (Symphonic Metal Ending)'}
#
#  {'Artist': 'RADIO TAPOK', 'Song': 'Nu Erismatimus (Symphonic Power Metal)'}
#
#  {'Artist': 'Aesma Daeva (Symphonic Metal)', 'Song': 'Darkness (arena 1999)'}
#
#  {'Artist': "Orion's Reign", 'Song': 'Carol of the Bells (Symphonic Heavy Metal Version)'}
#
#  {'Artist': 'Mr.69c', 'Song': 'Mozart Requiem (Symphonic Metal Version)'}
#
#  {'Artist': 'Epic Symphonic Rock', 'Song': 'Metallica II (Live)'}
#
#  {'Artist': "Orion's Reign", 'Song': 'Little Drummer Boy (Symphonic Metal Version)'}
#
#  {'Artist': 'Metal Militia', 'Song': 'Enter Sandman (Symphonic Version) (as made famous by Metallica)'}
#
#  {'Artist': 'Symphonic Beatz', 'Song': 'Metal Cap Mario'}
#
#  {'Artist': 'Symphonic Metamorphosis', 'Song': 'Sarabande'}
#
#  {'Artist': 'Lord Of The Lost', 'Song': 'Full Metal Ball (Full Metal Whore - Polished, Polite & Pc) (Swan Symphonies II Version)'}
#
#  {'Artist': 'Damn Yankees', 'Song': 'High Enough'}
#
#  {'Artist': 'All For Metal', 'Song': 'Welcome'}
#
#  {'Artist': 'Damn Yankees', 'Song': 'Runaway'}
#
#  {'Artist': 'All For Metal', 'Song': 'Gods Of Metal'}
#
#  {'Artist': 'FalKKonE', 'Song': 'Candle Queen'}
#
#  {'Artist': 'Damn Yankees', 'Song': 'Come Again'}
#
#  [{'Artist': 'Infinite Rock', 'Song': 'Symphonic Metal'}, {'Artist': 'The Tiberian Sons', 'Song': 'Mighty Wings (From "Top Gun") (Symphonic Metal Version)'}, {'Artist': 'Metal Militia', 'Song': 'Nothing Else Matters (Symphonic Version) (as made famous by Metallica)'}, {'Artist': 'Epic Symphonic Rock', 'Song': 'Metallica I (Live)'}, {'Artist': "Orion's Reign", 'Song': 'Santa Claus Is Coming to Town (Symphonic Heavy Metal Version)'}, {'Artist': 'NyxTheShield', 'Song': 'Black Apple (From "Underverse") (Symphonic Metal Version)'}, {'Artist': "Orion's Reign", 'Song': 'Thunderstruck (Symphonic Heavy Metal Version)'}, {'Artist': "Orion's Reign", 'Song': 'Joy to the World (Symphonic Heavy Metal Version)'}, {'Artist': 'BrunuhVille', 'Song': '[bonus] Lua Eterna (Symphonic Metal Ending)'}, {'Artist': 'RADIO TAPOK', 'Song': 'Nu Erismatimus (Symphonic Power Metal)'}, {'Artist': 'Aesma Daeva (Symphonic Metal)', 'Song': 'Darkness (arena 1999)'}, {'Artist': "Orion's Reign", 'Song': 'Carol of the Bells (Symphonic Heavy Metal Version)'}, {'Artist': 'Mr.69c', 'Song': 'Mozart Requiem (Symphonic Metal Version)'}, {'Artist': 'Epic Symphonic Rock', 'Song': 'Metallica II (Live)'}, {'Artist': "Orion's Reign", 'Song': 'Little Drummer Boy (Symphonic Metal Version)'}, {'Artist': 'Metal Militia', 'Song': 'Enter Sandman (Symphonic Version) (as made famous by Metallica)'}, {'Artist': 'Symphonic Beatz', 'Song': 'Metal Cap Mario'}, {'Artist': 'Symphonic Metamorphosis', 'Song': 'Sarabande'}, {'Artist': 'Lord Of The Lost', 'Song': 'Full Metal Ball (Full Metal Whore - Polished, Polite & Pc) (Swan Symphonies II Version)'}, {'Artist': 'Damn Yankees', 'Song': 'High Enough'}, {'Artist': 'All For Metal', 'Song': 'Welcome'}, {'Artist': 'Damn Yankees', 'Song': 'Runaway'}, {'Artist': 'All For Metal', 'Song': 'Gods Of Metal'}, {'Artist': 'FalKKonE', 'Song': 'Candle Queen'}, {'Artist': 'Damn Yankees', 'Song': 'Come Again'}]
